# %%
import pandas as pd
import numpy as np

# %matplotlib notebook
import matplotlib.pyplot as plt

from scipy import stats


df = pd.read_csv('../data/cexport.csv')

plt.figure()

slopes = []

for colname in df.columns:
    if 'rsi14' in colname:
        hist, edges = np.histogram(np.abs(df[df[colname] > -999][colname] / df[df[colname] > -999][colname].mean()), bins=15)
        hist = hist / np.sum(hist)
        edgebar = []
        raw_edges = []
        logvalues = []
        for lower, upper, val in zip(edges[:-1], edges[1:], hist):
            edgebar.append((lower+upper)/(2*np.mean(edges)))
            raw_edges.append((lower+upper)/2)
            logvalues.append(np.log10(val))
        slope, intercept, r_value, p_value, std_err = stats.linregress(edgebar, logvalues)
        if not np.isnan(slope):
            slopes.append(slope)
        plt.plot(edgebar, hist)
        plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\lutz.kuenneke\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:26: RuntimeWarning: divide by zero encountered in log10
# C:\Users\lutz.kuenneke\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3507: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   self.set_ylim(upper, lower, auto=None)

# %%
shist, sedges = np.histogram(slopes)

plt.figure()

plt.plot(sedges[:-1], shist)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
