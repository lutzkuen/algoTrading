# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot

df = pd.read_csv('importance.csv')

features= np.unique(df['label'])

max_importances = []

for feature in features:
    maxval = df[df['label'] == feature]['importance'].mean()
    max_importances.append({'feature': feature, 'importance': maxval })
max_importances = sorted(max_importances, key = lambda x: x.get('importance'), reverse=True)

for it in max_importances:
    print(it['feature'] + ' ' + str(it['importance']))
# Out:
# US30_USD_low 1351492530.9296875
# JP225_USD_low 1051456633.9375
# HK33_HKD_low 323235331.30078125
# US30_USD_high 291684781.2548828
# USD_CNH_close 222658861.4679069
# USD_HUF_high 142847153.42737436
# CN50_USD_high 99695832.66210938
# CN50_USD_low 91257768.3359375
# XAG_GBP_close 79239825.19801037
# NAS100_USD_low 58760857.38037109
# NAS100_USD_high 37412766.92199707
# XAU_CAD_ma60 27287561.365668524
# XAG_SGD_close 24250728.121427935
# DE30_EUR_low 23112023.47265625
# IN50_USD_high 17112348.45703125
# IN50_USD_low 12837033.606445312
# SPX500_USD_low 11393179.986618042
# XAG_SGD_ma60 10113875.329065446
# NZD_sentiment_Low Impact Expected_next 10012613.589543361
# USD_HUF_rsi14 5475173.10546875
# NZD_sentiment_Medium Impact Expected 5241178.302476476
# XAU_HKD_low 4591137.83412848
# XAU_HKD_close 4415660.5643747235
# XAG_SGD_rsi14 4345570.383872134
# USD_CZK_low 3861228.25
# XAG_EUR_close 3316471.1009531976
# XAG_GBP_madiff 3277645.126453057
# XAU_JPY_high 3084202.8444649866
# XAG_AUD_madiff 3045003.5024414062
# XAG_JPY_low 2802871.610779997
# XAU_USD_ma30 2694883.5225082343
# XAU_EUR_ma30 2406185.539572935
# USD_PLN_ma30 2227425.396484375
# US2000_USD_low 2225119.654319763
# XAG_EUR_ma30 1730040.6029779909
# XAU_JPY_low 1598052.4222499528
# USDNon-Economic 1539460.3836068106
# XAG_SGD_ma30 1470277.7313930125
# XAG_EUR_high 1449602.193567086
# USD_sentiment_Low Impact Expected 1443895.01584229
# NZD_sentiment_Medium Impact Expected_next2 1341598.4438970084
# XAG_NZD_high 1260330.8047034342
# XAU_SGD_ma60 1149450.3758009572
# USD_sentiment_Medium Impact Expected_next2 1127411.4594923558
# XAU_AUD_rsi14 1058979.8675546306
# XAG_HKD_high 1011582.171875
# USD_sentiment_Medium Impact Expected_next 976544.8899860082
# XAU_SGD_low 879341.2517109704
# USD_sentiment_High Impact Expected_next2 770914.707707844
# DE30_EUR_high 708697.9013671875
# XAG_USD_ma60 690492.3657978409
# XAG_GBP_rsi14 648512.5918431685
# XPT_USD_low 628453.2897933779
# USD_sentiment_Medium Impact Expected 626727.7185913333
# XAU_EUR_high 618899.0302445457
# XAG_SGD_madiff 554050.9348046902
# XAU_HKD_high 545748.8743645477
# XAU_SGD_rsi14 537304.3042120329
# EU50_EUR_high 536290.4961547853
# USD_sentiment_High Impact Expected_next 519728.04424216715
# XAU_GBP_rsi14 477010.21157580573
# XAU_USD_rsi14 464419.9957143878
# USD_sentiment_Low Impact Expected_next 462480.34257414774
# XAG_CAD_close 421176.2558553175
# XAU_USD_madiff 407252.5785035394
# XAG_USD_high 405460.45096606
# XAU_AUD_low 370276.7085692684
# XAU_XAG_low 355705.9744748391
# XAG_CHF_ma30 348272.64841811726
# XAU_SGD_ma30 274065.5548976039
# XAU_HKD_ma60 256241.08370915023
# XAU_XAG_ma60 231263.29676413196
# EU50_EUR_low 222057.88037109372
# HK33_HKD_high 218174.0
# XAU_EUR_vol 213636.1511538885
# USD_CZK_rsi14 213150.50545501712
# XAU_EUR_madiff 210784.8881443066
# XAU_CHF_high 201458.1718614083
# XAG_CAD_rsi14 199186.2103936207
# XAU_USD_ma60 190277.42524741293
# XAU_NZD_madiff 187244.95896856376
# XAU_XAG_vol 180942.4452755475
# XAU_AUD_close 178595.82807023186
# ZAR_JPY_madiff 173473.23746841753
# XPT_USD_madiff 172897.1646565646
# XAU_XAG_ma30 170986.36214442283
# XAU_HKD_rsi14 170632.60394401225
# XPD_USD_high 158175.73894923186
# XAU_USD_high 138612.27629285885
# XAG_NZD_ma60 135404.0136632933
# XAG_HKD_close 132313.86151548312
# USD_sentiment_High Impact Expected 129694.26088223845
# WHEAT_USD_vol 123939.06516557187
# XAG_EUR_ma60 119933.93655048311
# XAU_USD_low 113777.16571609906
# XAU_SGD_close 111735.46876787364
# XAU_USD_vol 109631.6868885487
# XAU_GBP_close 107399.26508679477
# XAU_XAG_high 97600.32933470693
# XAU_EUR_ma60 94419.77551430106
# XAG_HKD_ma60 93960.21271130737
# XAU_CHF_ma60 91333.06910753863
# XAU_CAD_madiff 89170.94154481571
# XAU_USD_close 89126.15917762928
# FR40_EUR_high 88510.31030273438
# weekday 84974.02223298031
# XAG_AUD_ma30 74430.34533590727
# XPT_USD_high 72582.95276719134
# XPT_USD_ma60 62282.62579501814
# XCU_USD_ma30 50848.99181278397
# XAG_NZD_low 50147.65354888237
# XAG_USD_madiff 46305.76996134043
# ZAR_JPY_ma30 40883.51164701941
# NL25_EUR_low 39828.918586730964
# XAG_GBP_low 35129.36936753243
# XAG_NZD_ma30 35061.83500192165
# XAG_NZD_vol 30370.86172728613
# XAG_CHF_rsi14 30272.946997148916
# USDMediumImpactExpected 29884.964889526367
# XCU_USD_vol 29409.48169819091
# XAU_CAD_high 28810.450630186366
# NZDMediumImpactExpected_next2 27363.238021850586
# UK100_GBP_low 26542.7001953125
# XPT_USD_rsi14 26513.600138997666
# XAU_SGD_madiff 24418.11191559863
# SG30_SGD_low 24030.32393074036
# XAU_GBP_ma60 22780.981008828378
# USDMediumImpactExpected_next2 22299.005859976012
# XAG_JPY_rsi14 20339.200728663713
# XAU_CHF_vol 20287.26812404971
# XAU_SGD_vol 19771.43449354672
# USDLowImpactExpected 18288.303015777947
# FR40_EUR_low 17038.0498046875
# XAG_JPY_high 15895.571179586772
# XAG_AUD_ma60 15075.497501855061
# XPD_USD_low 13892.08572827066
# XAU_CHF_rsi14 13358.550290530602
# TWIX_USD_high 12612.221620559692
# UK100_GBP_high 12402.840087890625
# XAU_NZD_rsi14 11433.0030081454
# AU200_AUD_low 10723.6904296875
# XAU_NZD_high 10653.347638331481
# XAU_AUD_ma30 10556.273092775018
# XAU_HKD_vol 10277.49832341145
# XAU_JPY_vol 10020.33699005195
# SPX500_USD_high 9413.200958251951
# USDMediumImpactExpected_next 8793.175561027314
# XAG_GBP_ma60 8392.693816542625
# XAU_CAD_low 7921.4533330987
# XAU_JPY_close 7246.7075102468425
# XPD_USD_rsi14 6899.145530453108
# XAG_USD_rsi14 6774.172554304829
# AU200_AUD_high 6682.8701171875
# NZD_sentiment_High Impact Expected 6499.75341119495
# USDHighImpactExpected_next 6056.35009765625
# XAU_XAG_close 6011.3912309043235
# XAG_CHF_ma60 5621.8817919105295
# XAU_XAG_rsi14 4967.413883558788
# XPT_USD_close 4025.1092023198016
# XAG_NZD_close 3882.114551986754
# ZAR_JPY_ma60 3848.5470302859376
# XCU_USD_ma60 3679.8288075520218
# XAU_NZD_close 3430.440116227073
# ZAR_JPY_low 3371.36242169894
# SG30_SGD_high 3246.0613384246826
# XAG_JPY_close 3238.084528537733
# IN50_USD_close 3224.6000779867168
# XAU_HKD_ma30 3162.0962781939234
# XPD_USD_vol 3111.9072522010692
# ZAR_JPY_vol 3086.3862580667824
# XAU_XAG_madiff 2782.3037562317472
# UK10YB_GBP_close 2486.1497673988347
# XAG_JPY_vol 2164.0394926071162
# EUR_HKD_close 2159.1497303247447
# UK100_GBP_close 2135.3902590870857
# XAU_AUD_high 1967.6705609826374
# XAU_JPY_ma30 1940.643012230875
# XAG_USD_low 1932.814311869221
# BCO_USD_low 1822.656018257141
# USD_MXN_close 1805.5232908725736
# NZD_sentiment_Medium Impact Expected_next 1740.3469633940676
# NL25_EUR_high 1732.094295501709
# XAG_USD_ma30 1605.9634879832183
# AUD_CHF_close 1547.6145286560059
# XAG_NZD_rsi14 1495.6223506381034
# XAG_USD_close 1357.419155136874
# EUR_USD_close 1277.6578889489176
# GBP_ZAR_close 1198.5506508350372
# XCU_USD_madiff 1132.5345361866637
# EUR_CAD_close 1025.0455503463743
# EUR_HUF_close 1019.0527698993684
# XAU_EUR_low 936.6747477478638
# US2000_USD_high 934.6329956054688
# NZD_USD_close 930.7658816576004
# JP225_USD_close 898.4878498315811
# XPD_USD_ma30 893.3584275546148
# CHF_ZAR_close 871.8134617805481
# USD_JPY_low 796.9994104802607
# EUR_CHF_close 793.62422144413
# ZAR_JPY_high 775.5660224220935
# USD_JPY_high 672.9587121456861
# NAS100_USD_close 615.2510239481926
# XAG_CAD_high 613.8912246350927
# USD_PLN_close 568.1043708324432
# XAU_NZD_vol 564.4193770817825
# EUR_SEK_close 560.9673310518265
# WTICO_USD_low 558.7700230851768
# USD_CAD_close 531.5365488529205
# XPT_USD_vol 520.5976958959221
# USB02Y_USD_close 474.3044203519821
# XPD_USD_close 437.05549444793155
# TRY_JPY_low 428.34515793621534
# CAD_JPY_low 414.835454672575
# USD_sentiment_Low Impact Expected_next2 414.138413058246
# ZAR_JPY_close 374.44506978085377
# XAU_EUR_rsi14 373.0658022860589
# XAU_NZD_ma30 352.89517536977064
# AUD_HKD_close 351.2612292766571
# XPT_USD_ma30 340.8975231655302
# AUD_JPY_low 339.0372005403042
# XAU_CHF_ma30 311.386120973144
# XAU_SGD_high 298.42934316945747
# XAU_GBP_low 281.9261556816311
# TWIX_USD_close 244.5315909385681
# USD_CZK_close 228.802809715271
# XAU_HKD_madiff 209.74769972951484
# XCU_USD_low 206.7532182993423
# SGD_HKD_close 195.5043811798096
# USD_TRY_high 190.80243345955387
# EUR_TRY_high 189.63467129762284
# USB05Y_USD_low 183.69257172360085
# EUR_JPY_high 182.3815593123436
# USD_INR_low 179.75784225575626
# EUR_ZAR_high 178.34960315562788
# USD_MXN_high 170.59821745008233
# ZAR_JPY_rsi14 168.07058601702758
# EUR_JPY_close 163.5450500249863
# XAU_CAD_close 162.94367676255231
# XAG_CHF_low 128.398809671402
# NATGAS_USD_high 127.31569474519348
# XAG_HKD_vol 127.16091978549956
# XAU_NZD_low 126.28466762412936
# CHF_JPY_low 120.68349808454514
# EUR_HUF_low 113.50688004493713
# USD_SGD_close 108.84208917617798
# CHF_ZAR_high 108.04914684034884
# SGD_JPY_high 107.91554339230059
# XAG_SGD_vol 106.54299926757812
# SPX500_USD_close 106.44496870040894
# GBP_ZAR_high 104.33359671011569
# USB10Y_USD_low 103.10893595218658
# XAG_USD_vol 96.54076968692243
# XAU_CAD_vol 95.40123017157566
# UK10YB_GBP_low 93.60382029414177
# XCU_USD_close 91.52957188391126
# XPD_USD_ma60 85.62915899245533
# AUD_CAD_close 76.37168002128602
# XAG_HKD_low 76.12002810835838
# XCU_USD_high 74.12820584831576
# XCU_USD_rsi14 73.96203608207045
# XAU_JPY_madiff 72.68976441460133
# WTICO_USD_vol 69.52817945927383
# XAU_NZD_ma60 66.25935182275154
# XAU_CAD_ma30 65.21057433910967
# USD_THB_low 61.79455604497343
# USD_CNH_low 60.77848785973471
# USB05Y_USD_close 60.271120429039
# EUR_CZK_high 59.59455968326075
# USD_DKK_close 58.7820303440094
# EUR_CZK_low 58.24162888234423
# TWIX_USD_low 57.49250030517578
# EUR_TRY_low 57.39743523538346
# USD_TRY_low 55.369268534821465
# XPD_USD_madiff 53.12810678216582
# XAG_EUR_rsi14 51.57982110697776
# XAG_GBP_high 37.45300042629243
# XAG_AUD_high 35.86608440987766
# XAG_JPY_madiff 31.870108262449502
# XAG_CAD_low 29.13789763683453
# USD_CNH_high 25.05561925494629
# GBP_ZAR_low 23.873211532831192
# USD_ZAR_close 23.482669830322266
# USD_THB_high 23.280249319970608
# XAU_JPY_rsi14 22.650399997981264
# XAU_AUD_vol 20.894179412862286
# XAG_EUR_low 17.6561287426933
# NL25_EUR_close 15.420040249824526
# USD_ZAR_low 14.627016179263592
# WHEAT_USD_low 14.462514179758728
# XAG_AUD_close 14.252808377146723
# XAU_AUD_madiff 13.772777549277635
# WHEAT_USD_ma30 13.747402548789976
# XAG_CHF_close 12.758866786956787
# XAU_JPY_ma60 12.452784385396184
# GBP_CHF_close 12.2669198513031
# USD_MXN_low 12.027378004044294
# EUR_AUD_close 11.975070238113403
# XAG_SGD_high 11.208782837460083
# WHEAT_USD_close 10.517719745635986
# XAU_CHF_madiff 10.008126947523253
# GBP_CAD_close 9.696969985961914
# EUR_ZAR_close 9.647949934005736
# SOYBN_USD_close 9.353060126304626
# NATGAS_USD_low 8.787958620814607
# XAU_GBP_ma30 8.695592307425864
# WHEAT_USD_ma60 7.491969972848892
# USD_JPY_close 7.362709760665893
# GBP_HKD_close 7.0138299465179434
# XAG_CAD_vol 6.918409761041403
# USD_JPY_rsi14 6.8065698188729575
# USD_HKD_close 6.757760047912598
# CHF_HKD_close 6.4728100299835205
# XAU_GBP_vol 6.119809195141637
# BCO_USD_close 6.044080018997192
# XAG_HKD_ma30 5.9886037099256555
# EU50_EUR_close 5.797900199890138
# GBP_AUD_close 5.699159860610963
# XAG_CHF_high 5.691166382282972
# USD_HUF_low 5.625969886779785
# NATGAS_USD_close 5.616230010986328
# USD_SAR_close 5.536210060119629
# XAG_NZD_madiff 5.255696346540935
# XAG_CAD_ma30 5.179589708785352
# USB05Y_USD_high 4.96755699068308
# CHF_JPY_close 4.787860155105591
# GBP_NZD_close 4.700940132141113
# HKD_JPY_high 4.644125858321786
# BCO_USD_high 4.3027299642562875
# USB10Y_USD_close 4.224030017852783
# USB30Y_USD_close 4.149289846420288
# XAG_CHF_madiff 4.083619105571415
# EUR_NOK_close 4.0741400718688965
# NZD_HKD_close 4.0412001609802255
# USD_SEK_close 3.906690001487732
# USD_HUF_close 3.771029949188232
# SUGAR_USD_close 3.7634599208831783
# HK33_HKD_close 3.712239980697632
# XAG_HKD_rsi14 3.684460197627939
# XAU_EUR_close 3.654720819750916
# WTICO_USD_high 3.554270679836918
# AUD_JPY_close 3.50777006149292
# CORN_USD_close 3.249550104141236
# USD_CHF_close 3.119329929351806
# XAU_GBP_madiff 3.1137472413330523
# USD_TRY_close 2.9192800521850586
# US2000_USD_close 2.769920110702514
# CHF_HKD_low 2.721615533635486
# USD_SGD_high 2.717471716043292
# HKD_JPY_close 2.6367299556732178
# GBP_USD_close 2.5688300132751465
# EUR_CZK_close 2.538739919662476
# FR40_EUR_close 2.517519950866699
# XAU_AUD_ma60 2.4894994066016807
# GBP_SGD_close 2.4798099994659424
# AUD_USD_close 2.4218099117279053
# NZD_SGD_close 2.411540031433105
# EUR_PLN_close 2.349630117416382
# CHF_JPY_high 2.19427202641964
# WHEAT_USD_high 2.1277173524722457
# XAU_CAD_rsi14 2.071721501448857
# CAD_JPY_high 1.9679090082645416
# CN50_USD_close 1.872089982032776
# NZD_CAD_close 1.8455400466918943
# SGD_JPY_low 1.5709159672260284
# NZD_JPY_low 1.4203400015830994
# USD_INR_high 1.0793100595474243
# XAU_CHF_close 1.0738718766369857
# AUD_JPY_high 1.0140480101108549
# DE10YB_EUR_low 0.8599889874458313
# XAG_JPY_ma30 0.8521950244903566
# TRY_JPY_high 0.6672860085964203
# XAG_CAD_ma60 0.6315945088863373
# NZD_JPY_high 0.6265239715576172
# XAG_JPY_ma60 0.5582636275992172
# USD_SGD_rsi14 0.5353260040283203
# CHF_HKD_high 0.4813686809502542
# SGD_HKD_low 0.4734883471974172
# CAD_HKD_high 0.4623076337156817
# USD_ZAR_high 0.3414746932685375
# NZD_sentiment_High Impact Expected_next2 0.31840234743431206
# XAG_HKD_madiff 0.28032049536705017
# USB02Y_USD_low 0.25906534120440483
# USD_HKD_low 0.2490727144336233
# HKD_JPY_low 0.2191441808827221
# DE10YB_EUR_high 0.2146649956703186
# USD_HKD_high 0.20701776617289624
# NZD_HKD_high 0.1984387703705579
# XAG_AUD_low 0.19348615035414696
# XAG_EUR_vol 0.16871149837970734
# EUR_NOK_high 0.1380346198566258
# EUR_SEK_low 0.1266061596106738
# AUD_HKD_high 0.11901294998824595
# EUR_HKD_high 0.11527534015476705
# USD_NOK_low 0.103031060192734
# GBP_AUD_low 0.08518404404458124
# EUR_PLN_low 0.08403969294158742
# GBP_NZD_high 0.06843290597316809
# GBP_USD_low 0.06610352660209172
# AUD_HKD_low 0.05824818997643887
# GBP_AUD_high 0.054545532810152515
# CHF_ZAR_low 0.054028399288654334
# SOYBN_USD_low 0.05316819995641709
# NZDNon-Economic 0.05091114498660924
# XAG_SGD_low 0.05042731460404563
# EUR_GBP_low 0.0482938288614605
# SOYBN_USD_high 0.047537099570035934
# NZD_SGD_high 0.04592373700779717
# USD_CZK_high 0.035220898687839515
# USB02Y_USD_high 0.03469931986182928
# USD_PLN_low 0.02949562791036442
# XAU_CHF_low 0.029352015840621398
# XAU_GBP_high 0.02840992437722889
# GBP_PLN_low 0.023768729995936155
# EUR_PLN_high 0.023751410946715627
# GBP_CHF_high 0.02264498925069347
# EUR_CHF_low 0.02258577055181377
# NZD_sentiment_Low Impact Expected 0.01955510093830526
# GBP_HKD_high 0.019453480374068025
# GBP_CAD_high 0.019262147921836004
# USD_CAD_low 0.01809922287793597
# EUR_NZD_low 0.01709216074232245
# SUGAR_USD_low 0.014895488642650891
# NZD_CHF_high 0.01281650140299462
# AUD_USD_low 0.012490753537349521
# XAG_EUR_madiff 0.010588497418211773
# CORN_USD_high 0.01054640021175146
# USD_SEK_low 0.010448090266436337
# NZD_HKD_low 0.010409049922600387
# USDNon-Economic_next 0.008252910717769905
# EUR_NZD_high 0.007897518036770634
# NZD_SGD_low 0.007472942183085252
# CORN_USD_low 0.006478019990026951
# USD_DKK_low 0.0060118199326097965
# GBP_USD_high 0.005878670039237478
# EUR_SEK_high 0.005112370010465384
# NZD_CAD_low 0.004212712199660018
# AUD_CHF_high 0.0042056407019117606
# EUR_DKK_high 0.003388638290971357
# EUR_DKK_low 0.003178789891535416
# SUGAR_USD_high 0.003137009215606668
# USD_DKK_high 0.002833330072462559
# CAD_CHF_high 0.0028048511012457307
# USD_SAR_high 0.002430759020800366
# AUD_SGD_high 0.0020030986961501185
# GBP_PLN_high 0.001957739936187864
# USD_SAR_low 0.0015204666740338268
# GBP_NZD_low 0.0010782900499179961
# USD_PLN_high 0.0010748599888756873
# SGD_HKD_high 0.0007826529908925295
# GBP_SGD_high 0.000750564293412026
# JPY_sentiment_Medium Impact Expected_next2 0.000697519380992162
# NZD_USD_high 0.00025109569833148265
# EUR_AUD_high 0.00022931299463380128
# EUR_USD_low 0.00021677240147255358
# XAG_GBP_ma30 0.0001833871992857894
# EUR_USD_high 0.00013098599811200984
# AUD_NZD_low 0.0001209484034916386
# EUR_CAD_high 0.00011838600039482117
# NZD_USD_low 0.000107564999780152
# USD_CHF_low 0.0001012623015412828
# NZD_CHF_low 9.774009959073736e-05
# CAD_SGD_high 8.455089846393093e-05
# USD_CHF_high 4.809969868802e-05
# USD_SGD_low 4.655040174839087e-05
# EUR_CHF_high 3.304369965917431e-05
# CAD_SGD_low 2.1919700884609483e-05
# AU200_AUD_close 0.0
# AUD_CAD_high 0.0
# AUD_CAD_low 0.0
# AUD_CHF_low 0.0
# AUD_NZD_close 0.0
# AUD_NZD_high 0.0
# AUD_SGD_close 0.0
# AUD_SGD_low 0.0
# AUD_USD_high 0.0
# CAD_CHF_close 0.0
# CAD_CHF_low 0.0
# CAD_HKD_close 0.0
# CAD_HKD_low 0.0
# CAD_JPY_close 0.0
# CAD_SGD_close 0.0
# DE10YB_EUR_close 0.0
# DE30_EUR_close 0.0
# EUR_AUD_low 0.0
# EUR_CAD_low 0.0
# EUR_DKK_close 0.0
# EUR_GBP_close 0.0
# EUR_GBP_high 0.0
# EUR_HKD_low 0.0
# EUR_HUF_high 0.0
# EUR_JPY_low 0.0
# EUR_NOK_low 0.0
# EUR_NZD_close 0.0
# EUR_SGD_close 0.0
# EUR_SGD_high 0.0
# EUR_SGD_low 0.0
# EUR_TRY_close 0.0
# EUR_ZAR_low 0.0
# GBP_CAD_low 0.0
# GBP_CHF_low 0.0
# GBP_HKD_low 0.0
# GBP_JPY_close 0.0
# GBP_JPY_high 0.0
# GBP_JPY_low 0.0
# GBP_PLN_close 0.0
# GBP_SGD_low 0.0
# JP225_USD_high 0.0
# JPYNon-Economic_next2 0.0
# JPY_sentiment_High Impact Expected 0.0
# JPY_sentiment_High Impact Expected_next 0.0
# JPY_sentiment_High Impact Expected_next2 0.0
# JPY_sentiment_Medium Impact Expected 0.0
# JPY_sentiment_Medium Impact Expected_next 0.0
# JPY_sentiment_Non-Economic 0.0
# JPY_sentiment_Non-Economic_next 0.0
# JPY_sentiment_Non-Economic_next2 0.0
# NZDNon-Economic_next 0.0
# NZDNon-Economic_next2 0.0
# NZD_CAD_high 0.0
# NZD_CHF_close 0.0
# NZD_JPY_close 0.0
# NZD_sentiment_High Impact Expected_next 0.0
# NZD_sentiment_Low Impact Expected_next2 0.0
# NZD_sentiment_Non-Economic 0.0
# NZD_sentiment_Non-Economic_next 0.0
# NZD_sentiment_Non-Economic_next2 0.0
# SG30_SGD_close 0.0
# SGD_CHF_close 0.0
# SGD_CHF_high 0.0
# SGD_CHF_low 0.0
# SGD_JPY_close 0.0
# TRY_JPY_close 0.0
# UK10YB_GBP_high 0.0
# US30_USD_close 0.0
# USB10Y_USD_high 0.0
# USB30Y_USD_high 0.0
# USB30Y_USD_low 0.0
# USDHighImpactExpected_next2 0.0
# USDNon-Economic_next2 0.0
# USD_CAD_high 0.0
# USD_INR_close 0.0
# USD_NOK_close 0.0
# USD_NOK_high 0.0
# USD_SEK_high 0.0
# USD_THB_close 0.0
# USD_sentiment_Non-Economic 0.0
# USD_sentiment_Non-Economic_next 0.0
# USD_sentiment_Non-Economic_next2 0.0
# WHEAT_USD_madiff 0.0
# WHEAT_USD_rsi14 0.0
# WTICO_USD_close 0.0
# WTICO_USD_madiff 0.0
# XAG_AUD_rsi14 0.0
# XAG_CHF_vol 0.0
# XAG_GBP_vol 0.0

# %%
mean_gain = df['importance'].mean()

knockout_threshold = mean_gain / 2
knockstr = ''
for it in max_importances:
    if it['importance'] <= mean_gain:
        knockstr += "'" + it['feature'] + "',"
print(knockstr)
# Out:
# 'USD_sentiment_Medium Impact Expected_next2','XAU_AUD_rsi14','XAG_HKD_high','USD_sentiment_Medium Impact Expected_next','XAU_SGD_low','USD_sentiment_High Impact Expected_next2','DE30_EUR_high','XAG_USD_ma60','XAG_GBP_rsi14','XPT_USD_low','USD_sentiment_Medium Impact Expected','XAU_EUR_high','XAG_SGD_madiff','XAU_HKD_high','XAU_SGD_rsi14','EU50_EUR_high','USD_sentiment_High Impact Expected_next','XAU_GBP_rsi14','XAU_USD_rsi14','USD_sentiment_Low Impact Expected_next','XAG_CAD_close','XAU_USD_madiff','XAG_USD_high','XAU_AUD_low','XAU_XAG_low','XAG_CHF_ma30','XAU_SGD_ma30','XAU_HKD_ma60','XAU_XAG_ma60','EU50_EUR_low','HK33_HKD_high','XAU_EUR_vol','USD_CZK_rsi14','XAU_EUR_madiff','XAU_CHF_high','XAG_CAD_rsi14','XAU_USD_ma60','XAU_NZD_madiff','XAU_XAG_vol','XAU_AUD_close','ZAR_JPY_madiff','XPT_USD_madiff','XAU_XAG_ma30','XAU_HKD_rsi14','XPD_USD_high','XAU_USD_high','XAG_NZD_ma60','XAG_HKD_close','USD_sentiment_High Impact Expected','WHEAT_USD_vol','XAG_EUR_ma60','XAU_USD_low','XAU_SGD_close','XAU_USD_vol','XAU_GBP_close','XAU_XAG_high','XAU_EUR_ma60','XAG_HKD_ma60','XAU_CHF_ma60','XAU_CAD_madiff','XAU_USD_close','FR40_EUR_high','weekday','XAG_AUD_ma30','XPT_USD_high','XPT_USD_ma60','XCU_USD_ma30','XAG_NZD_low','XAG_USD_madiff','ZAR_JPY_ma30','NL25_EUR_low','XAG_GBP_low','XAG_NZD_ma30','XAG_NZD_vol','XAG_CHF_rsi14','USDMediumImpactExpected','XCU_USD_vol','XAU_CAD_high','NZDMediumImpactExpected_next2','UK100_GBP_low','XPT_USD_rsi14','XAU_SGD_madiff','SG30_SGD_low','XAU_GBP_ma60','USDMediumImpactExpected_next2','XAG_JPY_rsi14','XAU_CHF_vol','XAU_SGD_vol','USDLowImpactExpected','FR40_EUR_low','XAG_JPY_high','XAG_AUD_ma60','XPD_USD_low','XAU_CHF_rsi14','TWIX_USD_high','UK100_GBP_high','XAU_NZD_rsi14','AU200_AUD_low','XAU_NZD_high','XAU_AUD_ma30','XAU_HKD_vol','XAU_JPY_vol','SPX500_USD_high','USDMediumImpactExpected_next','XAG_GBP_ma60','XAU_CAD_low','XAU_JPY_close','XPD_USD_rsi14','XAG_USD_rsi14','AU200_AUD_high','NZD_sentiment_High Impact Expected','USDHighImpactExpected_next','XAU_XAG_close','XAG_CHF_ma60','XAU_XAG_rsi14','XPT_USD_close','XAG_NZD_close','ZAR_JPY_ma60','XCU_USD_ma60','XAU_NZD_close','ZAR_JPY_low','SG30_SGD_high','XAG_JPY_close','IN50_USD_close','XAU_HKD_ma30','XPD_USD_vol','ZAR_JPY_vol','XAU_XAG_madiff','UK10YB_GBP_close','XAG_JPY_vol','EUR_HKD_close','UK100_GBP_close','XAU_AUD_high','XAU_JPY_ma30','XAG_USD_low','BCO_USD_low','USD_MXN_close','NZD_sentiment_Medium Impact Expected_next','NL25_EUR_high','XAG_USD_ma30','AUD_CHF_close','XAG_NZD_rsi14','XAG_USD_close','EUR_USD_close','GBP_ZAR_close','XCU_USD_madiff','EUR_CAD_close','EUR_HUF_close','XAU_EUR_low','US2000_USD_high','NZD_USD_close','JP225_USD_close','XPD_USD_ma30','CHF_ZAR_close','USD_JPY_low','EUR_CHF_close','ZAR_JPY_high','USD_JPY_high','NAS100_USD_close','XAG_CAD_high','USD_PLN_close','XAU_NZD_vol','EUR_SEK_close','WTICO_USD_low','USD_CAD_close','XPT_USD_vol','USB02Y_USD_close','XPD_USD_close','TRY_JPY_low','CAD_JPY_low','USD_sentiment_Low Impact Expected_next2','ZAR_JPY_close','XAU_EUR_rsi14','XAU_NZD_ma30','AUD_HKD_close','XPT_USD_ma30','AUD_JPY_low','XAU_CHF_ma30','XAU_SGD_high','XAU_GBP_low','TWIX_USD_close','USD_CZK_close','XAU_HKD_madiff','XCU_USD_low','SGD_HKD_close','USD_TRY_high','EUR_TRY_high','USB05Y_USD_low','EUR_JPY_high','USD_INR_low','EUR_ZAR_high','USD_MXN_high','ZAR_JPY_rsi14','EUR_JPY_close','XAU_CAD_close','XAG_CHF_low','NATGAS_USD_high','XAG_HKD_vol','XAU_NZD_low','CHF_JPY_low','EUR_HUF_low','USD_SGD_close','CHF_ZAR_high','SGD_JPY_high','XAG_SGD_vol','SPX500_USD_close','GBP_ZAR_high','USB10Y_USD_low','XAG_USD_vol','XAU_CAD_vol','UK10YB_GBP_low','XCU_USD_close','XPD_USD_ma60','AUD_CAD_close','XAG_HKD_low','XCU_USD_high','XCU_USD_rsi14','XAU_JPY_madiff','WTICO_USD_vol','XAU_NZD_ma60','XAU_CAD_ma30','USD_THB_low','USD_CNH_low','USB05Y_USD_close','EUR_CZK_high','USD_DKK_close','EUR_CZK_low','TWIX_USD_low','EUR_TRY_low','USD_TRY_low','XPD_USD_madiff','XAG_EUR_rsi14','XAG_GBP_high','XAG_AUD_high','XAG_JPY_madiff','XAG_CAD_low','USD_CNH_high','GB ...
